# %% [markdown]
# ## Splitting Data from Path Reports

# %%
#import statements
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
import re
import difflib as dl
import nltk
from sklearn.model_selection import train_test_split

# %%
#import data
data = pd.read_csv("PathReport&Labels.csv")
data = data.replace(to_replace='bresat', value='breast', regex=True)
data = data.replace(to_replace='cancinoma', value='carcinoma', regex=True)
data.columns = ["Path Report", "Label"]
numPatients = data.shape[0]

# %%
letters = "A[).:]| B[).:]| C[).:]| D[).:]| E[).:]| F[).:]| G[).:]| H[).:]| I[).:]| J[).:]| K[).:]"

# %%
#split by specimen
for i in range(0, len(data)):
    if data['Path Report'].iloc[i][0:2] not in ['A.', 'A)', 'A:']:
        data['Path Report'].iloc[i] = 'A. ' + data['Path Report'].iloc[i]
splitReps = []
for pathRep in data["Path Report"]:
    splitRep = re.split(letters, pathRep)
    if len(splitRep) > 1:
        splitRep = splitRep[1:]
    splitReps.append(splitRep)

# %%
#cell for testing issues with splitting of individual specimens
re.split("A[).:] | B[).:]|C[).:]", "A:Left Breast at 3:00 , Fine Needle Aspiration: Adenocarcinoma, see comment. B:Left Breast at 2:30, Fine Needle Aspiration: Adenocarcinoma, see comment.")
# Out:
# ['A:Left Breast at 3:00 , Fine Needle Aspiration: Adenocarcinoma, see comment.',
#  'Left Breast at 2:30, Fine Needle Aspiration: Adenocarcinoma, see comment.']

# %%
#setup DataFrame for biopsy data, extract information and place in appropriate columns
biopData = pd.DataFrame(columns = ["Patient", "Biopsy Description", "Path Report", "Rad Label", "Laterality"])

# %%
patIds = range(data.shape[0])
bioType, pathRep, patients, labels = [], [], [], []

for patId in patIds:
    patient = data.iloc[patId]
    for rep in patient[2]:
        #split report into biopsy description and path report
        splitRep = re.split(re.compile(r"\:|\. "), rep)
        if len(splitRep[0]) < 2:
            splitRep = re.split(re.compile(r"\:"), rep)
        
        if len(splitRep) > 1:
            bioType.append(splitRep[0])
            pathRep.append('. '.join(splitRep[1:]))
            patients.append(patId)
            labels.append(patient["Label"])
            
biopData["Patient"] = patients
biopData["Biopsy Description"] = bioType
biopData["Path Report"] = pathRep
biopData["Rad Label"] = labels

# %%
# Extracting laterality, biopsy source, and labels
lats, organs = [], []
for biop in biopData["Biopsy Description"]:
    biop = nltk.word_tokenize(biop.lower())

    if len(dl.get_close_matches("left", biop)) > 0:
        lats.append("left")
    elif len(dl.get_close_matches("right", biop)) > 0:
        lats.append("right")
    else:
        lats.append("na")

    if len(dl.get_close_matches("breast", biop)) > 0:
        organs.append("breast")
    elif len(dl.get_close_matches("nipple", biop)) > 0:
        organs.append("breast")
    elif len(dl.get_close_matches("mastectomy", biop)) > 0:
        organs.append("breast")
    elif len(dl.get_close_matches("lymph", biop)) > 0:
        organs.append("lymph node")
    elif len(dl.get_close_matches("skin", biop)) > 0:
        organs.append("skin")
    elif len([word for wordList in [dl.get_close_matches(br, biop) 
            for br in ["axilla", "uterus", "fallopian", "ovary", "adnexa"]] 
              for word in wordList]) > 0:
        organs.append("uterus")
    else:
        organs.append("na")
biopData["Laterality"] = lats
biopData["Biopsy Source"] = organs

numSamples = biopData.shape[0]

biopData
#keeping only breast specimens per research specification 
biopData2= biopData[biopData["Biopsy Source"] == 'breast']
#fix indexing issue due to dropped specimens
k = biopData2.reset_index()
k2 = k.drop(labels='index', axis=1)
# Out:
# "30 o'clock, 2 cm from nipple), needle biopsy.  Invasive ductal carcinoma, consistent with recurrent ductal carcinoma of the breast; see comment."

# %%
#Testing
biopData
# Out:
#       Patient                                 Biopsy Description  \
# 0           0                    Breast, left, simple mastectomy
# 1           0               Lymph node, sentinel node #1, biopsy
# 2           0               Lymph node, sentinel node #2, biopsy
# 3           0            Lymph node, nonsentinel node #3, biopsy
# 4           0                   Breast, right, simple mastectomy
# 5           1   Left breast, "mass at 12 o'clock 3 cm from ni...
# 6           1   Right breast, 10 o'clock 4 cm from nipple, ne...
# 7           2                  Right axillary contents, excision
# 8           2                       Skin, right axilla, excision
# 9           2                             Right nipple, excision
# 10          3      Right breast, excision of mammographic lesion
# 11          4        Sentinel lymph node #1, left axilla, biopsy
# 12          4        Sentinel lymph node #2, left axilla, biopsy
# 13          4     Nonsentinel lymph node #3, left axilla, biopsy
# 14          4        Right breast, skin-sparing total mastectomy
# 15          4                Right breast, nipple tissue, biopsy
# 16          4         Left breast, skin-sparing total mastectomy
# 17          4                           Left breast, re-excision
# 18          4                        Left breast, nipple, biopsy
# 19          5                                Left breast, biopsy
# 20          5                                     Breast, biopsy
# 21          6                                     Left breast, 9
# 22          7                            Left breast, mastectomy
# 23          7       Medial superior margin left breast, excision
# 24          8   Lymph node, right axillary, sentinel node #1,...
# 25          8                           Right breast, mastectomy
# 26          8   Right breast, upper-inner quadrant, final ant...
# 27          8                  Soft tissue, right nipple, biopsy
# 28          8     Lymph nodes, levels 1 and 2, right, dissection
# 29          9                 Breast, left, "12 o'clock," biopsy
# ...       ...                                                ...
# 7018     3657                Left Breast, Fine Needle Aspiration
# 7019     3658                Left Breast, Fine Needle Aspiration
# 7020     3659                Left Breast, Fine Needle Aspiration
# 7021     3660                Left Breast, Fine Needle Aspiration
# 7022     3661                Left Breast, Fine Needle Aspiration
# 7023     3662                Left Breast, Fine Needle Aspiration
# 7024     3663                Left Breast, Fine Needle Aspiration
# 7025     3664                Left Breast, Fine Needle Aspiration
# 7026     3665                Left Breast, Fine Needle Aspiration
# 7027     3666                Left Breast, Fine Needle Aspiration
# 7028     3667                Left Breast, Fine Needle Aspiration
# 7029     3668                Left Breast, Fine Needle Aspiration
# 7030     3669                Left Breast, Fine Needle Aspiration
# 7031     3670                Left Breast, Fine Needle Aspiration
# 7032     3671                Left Breast, Fine Needle Aspiration
# 7033     3672                Left Breast, Fine Needle Aspiration
# 7034     3673                Left Breast, Fine Needle Aspiration
# 7035     3674               Right Breast, Fine Needle Aspiration
# 7036     3674   Right Axillary Lymph Node, Fine Needle Aspira...
# 7037     3675               Right Breast, Fine Needle Aspiration
# 7038     3675   Right Axillary Lymph Node, Fine Needle Aspira...
# 7039     3676    Subareolar Mass, Breast, Fine Needle Aspiration
# 7040     3677                     Lymph node, "sentinel", biopsy
# 7041     3677                  Lymph node, "sentinel #2", biopsy
# 7042     3678   Breast, 11 o'clock, 4 cm from nipple, needle ...
# 7043     3679                 Breast, side not specified, biopsy
# 7044     3680   Anterior inferior medial breast margin, re-ex...
# 7045     3680   Anterior superior medial breast margin, re-ex...
# 7046     3681                         Breast, needle core biopsy
# 7047     3681   2 Blocks Cancer Center Bank, 6/9/08, MR# 0824...
#
#                                             Path Report       Rad Label  \
# 0      1. Invasive lobular carcinoma in a background...   Left Positive
# 1                     No tumor in one lymph node (0/1).   Left Positive
# 2                     No tumor in one lymph node (0/1).   Left Positive
# 3                     No tumor in one lymph node (0/1).   Left Positive
# 4      1. Sclerosing papilloma; see comment. 2. Radi...   Left Positive
# 5      1. Invasive ductal carcinoma; see comment. 2....   Left Positive
# 6      Dense sclerotic fibrous tissue with scant ben...   Left Positive
# 7                No carcinoma in 10 lymph nodes (0/10).        Negative
# 8                                    Intradermal nevus.        Negative
# 9      1. Skin of nipple with underlying lactiferous...        Negative
# 10     1. Ductal carcinoma in situ (DCIS), intermedi...  Right Positive
# 11                    No tumor in one lymph node (0/1).   Left Positive
# 12                    No tumor in one lymph node (0/1).   Left Positive
# 13                 No tumor in three lymph nodes (0/3).   Left Positive
# 14     1. No in situ or invasive carcinoma. 2. Lobul...   Left Positive
# 15                             Breast tissue, no tumor.   Left Positive
# 16     1. Residual invasive ductal carcinoma, 0.5 cm...   Left Positive
# 17                       Fibroadipose tissue, no tumor.   Left Positive
# 18                             Breast tissue, no tumor.   Left Positive
# 19     1. Infiltrating ductal carcinoma, moderately ...   Left Positive
# 20     Low grade ductal carcinoma in-situ (DCIS), se...   Left Positive
# 21    30, needle core biopsy.  Invasive ductal carci...   Left Positive
# 22     1. Ductal carcinoma in situ, intermediate and...   Left Positive
# 23     Mature adipose tissue, no breast epithelial u...   Left Positive
# 24     1. No tumor in one lymph node (0/1). 2. Scarr...  Right Positive
# 25     1. No residual invasive carcinoma. 2. Focal e...  Right Positive
# 26     Benign fibroadipose tissue. No tumor or breas...  Right Positive
# 27                         Benign dense fibrous tissue.  Right Positive
# 28     No tumor in fourteen lymph nodes (0/14), two ...  Right Positive
# 29     Pleomorphic lobular carcinoma in situ; see co...   Left Positive
# ...                                                 ...             ...
# 7018                      Adenocarcinoma (see comment).   Left Positive
# 7019                       Adenocarcinoma; see comment.   Left Positive
# 7020                       Adenocarcinoma; see comment.   Left Positive
# 7021                       Adenocarcinoma; see comment.   Left Positive
# 7022                       Adenocarcinoma; see comment.   Left Positive
# 7023                       Adenocarcinoma; see comment.   Left Positive
# 7024                      Adenocarcinoma (see comment).   Left Positive
# 7025                       Adenocarcinoma; see comment.   Left Positive
# 7026                       Adenocarcinoma; see comment.   Left Positive
# 7027                       Adenocarcinoma; see comment.   Left Positive
# 7028                       Adenocarcinoma; see comment.   Left Positive
# 7029                       Adenocarcinoma; see comment.   Left Positive
# 7030                       Adenocarcinoma; see comment.   Left Positive
# 7031                       Adenocarcinoma; see comment.   Left Positive
# 7032                      Adenocarcinoma (see comment).   Left Positive
# 7033                       Adenocarcinoma; see comment.   Left Positive
# 7034                       Adenocarcinoma; see comment.   Left Positive
# 7035                       Adenocarcinoma; see comment.  Right Positive
# 7036            Metastatic adenocarcinoma; see comment.  Right Positive
# 7037                       Adenocarcinoma; see comment.  Right Positive
# 7038            Metastatic adenocarcinoma; see comment.  Right Positive
# 7039                       Adenocarcinoma; see comment.    Positive NOS
# 7040   Metastatic adenocarcinoma in one lymph node (...    Positive NOS
# 7041   Metastatic adenocarcinoma in one lymph node (...    Positive NOS
# 7042   1. Invasive ductal carcinoma; see comment. 2....    Positive NOS
# 7043   Ductal carcinoma in situ, high grade, solid p...    Positive NOS
# 7044   1. Severe atypical ductal hyperplasia with mi...    Positive NOS
# 7045   1. Microscopic foci of ductal carcinoma in si...    Positive NOS
# 7046   Ductal carcinoma in situ, nuclear grade 2-3; ...    Positive NOS
# 7047   Small foci of atypical ductal hyperplasia, no...    Positive NOS
#
#      Laterality Biopsy Source
# 0          left        breast
# 1            na    lymph node
# 2            na    lymph node
# 3            na    lymph node
# 4         right        breast
# 5          left        breast
# 6         right        breast
# 7         right        uterus
# 8         right          skin
# 9         right        breast
# 10        right        breast
# 11         left    lymph node
# 12         left    lymph node
# 13         left    lymph node
# 14        right        breast
# 15        right        breast
# 16         left        breast
# 17         left        breast
# 18         left        breast
# 19         left        breast
# 20           na        breast
# 21         left        breast
# 22         left        breast
# 23         left        breast
# 24        right    lymph node
# 25        right        breast
# 26        right        breast
# 27        right        breast
# 28        right    lymph node
# 29         left        breast
# ...         ...           ...
# 7018       left        breast
# 7019       left        breast
# 7020       left        breast
# 7021       left        breast
# 7022       left        breast
# 7023       left        breast
# 7024       left        breast
# 7025       left        breast
# 7026       left        breast
# 7027       left        breast
# 7028       left        breast
# 7029       left        breast
# 7030       left        breast
# 7031       left        breast
# 7032       left        breast
# 7033       left        breast
# 7034       left        breast
# 7035      right        breast
# 7036      right    lymph node
# 7037      right        breast
# 7038      right    lymph node
# 7039         na        breast
# 7040         na    lymph node
# 7041         na    lymph node
# 7042         na        breast
# 7043         na        breast
# 7044         na        breast
# 7045         na        breast
# 7046         na        breast
# 7047         na            na
#
# [7048 rows x 6 columns]

# %%
#Testing
k2.iloc[4744]
# Out:
# Patient                                                            3190
# Biopsy Description                 Skin, left superior breast, excision
# Path Report            Skin and breast tissue with no significant pa...
# Rad Label                                                Right Positive
# Laterality                                                         left
# Biopsy Source                                                    breast
# Name: 4744, dtype: object

# %%
#export completed 
data.to_csv("Path Reports Complete.csv")
k2.to_csv("Path Reports (By Specimens).csv")
biopData.to_csv('Path Reports by Specimens for All')
