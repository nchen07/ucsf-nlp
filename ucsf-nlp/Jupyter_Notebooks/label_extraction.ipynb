# %% [markdown]
# ## Labeling Path Reports

# %%
#import tools
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
import re
import difflib as dl
import nltk
from sklearn.model_selection import train_test_split

# %%
#import data
data = pd.read_csv("PathReport&Labels.csv")
data.columns = ["Path Report", "Label"]
numPatients = data.shape[0]
path_reports = pd.read_csv("Path Reports Complete.csv")
split_reps = pd.read_csv("Path Reports by Specimens for All").drop("Unnamed: 0", axis=1)
split_reps = split_reps.fillna('')

# %%
# natural language processing tools

# Negation Processing, applies _not identifier to words following a negation word
def negate_sequence(tokens):
    """
    Detects negations and transforms negated words into "not_" form.
    """
    negation = False
    delims = "?.!:;-"
    result = []
    for token in tokens:
        if any(c == token for c in delims):
            negation = False

        negated = "not_" + token if negation else token
        result.append(negated)

        if any(neg == token.lower() for neg in ["not", "n't", "no", "without", "negative", "treated"]):
            negation = True
            result[-1] = "not_" + result[-1]
            if len(result) > 1:
                result[-2] = "not_" + result[-2]

    return result

# %% [markdown]
# ## Classify Each Biopsy according to Path Tree

# %%
def classify_regex(pathRep):
    fx_path_rep = re.compile(r'(\=|\-)').sub(' ', pathRep)
    pathRep = ' '.join(negate_sequence(nltk.word_tokenize(fx_path_rep.lower())))
    
    obs = re.split(re.compile(r"[0-9][ ]?\. "), pathRep)
    #if len(obs) > 1:
    #    obs = obs[1:]
    obs = [re.compile(r'(\.|\;|\-|\,)').sub(' ', ' ' + ob + ' ') for ob in obs] 
    
    print(obs)
    # pad with spaces to match markers that come at beginning of strings and remove dashes and commas
    classes = []
    for ob in obs:
        classes.append(classify_breast_ob(ob))
    return classes

atyp_markers = ["flat epithelial atypia", 
                "atypical ductal hyperplasia", 
                "atypical lobular hyperplasia"]

fibro_markers = ["fibroadenoma", "phyllodes"]

ben_markers = ["papilloma", "usual ductal hyperplasia", 
                "apocrine metaplasia", "radial scar",
                "sclerosing adenosis", 
                "pseudoangiomatous stromal hyperplasia",
                "cyst", "mastitis", "benign"]

def classify_breast_ob(ob):
    print(ob)
    label = ["na", "na", "na"]

    # Lymphoma
    if re.search(" lymphoma", ob):
        label[0] = "lymphoma"
        return label
    
    

    # Breast Cancer and Metastases
    if re.search(" lcis", ob) or re.search(" lobular carcinoma in situ", ob):
        label = ["breast cancer", "lobular", "in situ"]
        return label
    elif re.search(" dcis", ob) or re.search(" ductal carcinoma in situ", ob):
        label = ["breast cancer", "ductal", "in situ"]
        return label
    elif re.search(" idc", ob) or re.search(" invasive ductal carcinoma", ob):
        label = ["breast cancer", "ductal", "invasive"]
        return label
    elif re.search(" ilc", ob) or re.search(" invasive lobular carcinoma", ob):
        label = ["breast cancer", "ductal", "invasive"]
        return label
    elif re.search(" lobular carcinoma", ob):
        label = ["breast cancer", "lobular", "na"]
        return label
    elif re.search(" ductal carcinoma", ob):
        label = ["breast cancer", "ductal", "na"]
        return label
    elif re.search(" low grade neoplasm", ob):
        label = ["breast cancer", "neoplasm", "na"]
        return label
    
    if re.search(" carcinoma| cancer| malign| adenocarcinoma| Adenocarcinoma", ob):
        label[0] = "breast cancer"
        if re.search(re.compile("[ -]invasive|[ -]infiltrating"), ob):
            label[2] = "invasive"
        elif re.search(re.compile("in[ -]situ"), ob):
            label[2] = "in situ"
        if re.search(" duct(al)?", ob):
            label[1] = "ductal"
        elif re.search("lobular", ob):
            label[1] = "lobular"
        print(label)
        return label
    if re.search(" metastati(c|s)", ob):
            #if organ == "breast":    
        label[2] = "metastasis"
            #else:
            #    label[0] = "metastasis from non-bc"
    
    

    # Atypical
    for marker in atyp_markers:
        if re.search(" " + marker + " ", ob):
            label[0] = "atypical"
            label[1] = marker
            return label
    
    # Fibroepithelial
    for marker in fibro_markers:
        if re.search(" " + marker + " ", ob):
            label[0] = "fibroepithelial"
            label[1] = marker
            return label
            
    # Benign
    for marker in ben_markers:
        if re.search(" " + marker + " ", ob):
            label[0] = "benign"
            label[1] = marker
            return label
            
    return label
            
    #lymph_marker = re.compile(" lymphoma")
    #mets_marker = re.compile(" metastasis")
    #inv_breast_marker = [re.compile(marker) for marker in []]

# %% [markdown]
# ## Merge labels for each specimen into 1 label by taking the worst of each label

# %%
def get_single_label(obs_labels):
    label = ["na", "na", "na"]
    first_level = [labels[0] for labels in obs_labels]
    second_level = [labels[1] for labels in obs_labels]
    
    try: 
        if "metastasis" in [labels[2] for labels in obs_labels]:
            label[2] = "metastasis"
        if "lymphoma" in first_level:
            label[0] = "lymphoma"
        #elif "metastasis from non-bc" in first_level:
        #    label[0] = "metastasis from non-bc"
        elif "breast cancer" in first_level:
            label[0] = "breast cancer"
            if "neoplasm" in [labels[1] for labels in obs_labels]:
                label[1] = "neoplasm"
            
            second_level = [labels[2] for labels in obs_labels]
            third_level = [labels[1] for labels in obs_labels]
            if "metastasis" in second_level:
                label[2] = "metastasis"
            else:
                if "invasive" in second_level:
                    label[2] = "invasive"
                    third_level = [third_level[ind] for ind in range(len(obs_labels)) 
                                   if second_level[ind] == "invasive"]
                elif "in situ" in second_level:
                    label[2] = "in situ"
                    third_level = [third_level[ind] for ind in range(len(obs_labels)) 
                                   if second_level[ind] == "in situ"]

                if "ductal" in third_level:
                    label[1] = "ductal"
                elif "lobular" in third_level:
                    label[1] = "lobular"
        elif "atypical" in first_level:
            label[0] = "atypical"
            for marker in atyp_markers:
                if marker in second_level:
                    label[1] = marker
        elif "fibroepithelial" in first_level:
            label[0] = "atypical"
            for marker in fibro_markers:
                if marker in second_level:
                    label[1] = marker
        elif "benign" in first_level:
            label[0] = "benign"
            for marker in ben_markers:
                if marker in second_level:
                    if marker != 'benign':
                        label[1] = marker
    except:
        print(obs_labels)
                
    return tuple(label)

# %% [markdown]
# ## Exporting

# %%
split_reps["Single Label"] = split_reps["All Labels"].apply(get_single_label)
split_reps.to_csv("k3.csv")

# %%
labeled_split_reps = split_reps.drop("Rad Label", axis=1).rename(index=str, 
    columns={"Patient": "Patient ID", 
             "Biopsy Description": "Path Report I",
             "Path Report": "Path Report II",
             "Laterality": "Laterality [Derived]",
             "Biopsy Source": "Organ [Derived]",
             "All Labels": "All Labels [Derived]",
             "Single Label": "Single Label [Derived]"})

# %%
#get a single label instead of the 3-part labels which indicated only cancer/atypical/benign/none without detail
def get_binary_label(patient_data):
    laterality = []
    for i, specimen in patient_data.iterrows():
        if specimen["Single Label [Derived]"][0] == "breast cancer" or specimen["Single Label [Derived]"][0] == "lymphoma" or specimen["Single Label [Derived]"][2]=="metastasis":
            laterality.append(specimen["Laterality [Derived]"])
    if "right" in laterality and "left" in laterality:
        return "Bilateral Positive"
    elif "right" in laterality:
        return "Right Positive"
    elif "left" in laterality:
        return "Left Positive"
    elif laterality:
        return "Positive NOS"
    else:
        return "Negative"

def flatten_list(nestedl):
    [item for sublist in nestedl for item in sublist]

patient_labels, binary_labels = [], []
for patID in range(numPatients):
    reps = labeled_split_reps[(labeled_split_reps["Patient ID"] == patID)]
    labels = reps["Single Label [Derived]"].tolist()
    single_label = get_single_label(labels)
    patient_labels.append(single_label)
    binary_labels.append(get_binary_label(reps))
    
    

labeled_data = data
labeled_data["Single Label"] = patient_labels
labeled_data["Binary Label [Derived]"] = binary_labels
labeled_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-05f28b8081a7> in <module>()
#      20
#      21 patient_labels, binary_labels = [], []
# ---> 22 for patID in range(numPatients):
#      23     reps = labeled_split_reps[(labeled_split_reps["Patient ID"] == patID)]
#      24     labels = reps["Single Label [Derived]"].tolist()
#
# NameError: name 'numPatients' is not defined

# %%
# Testing
k5 = labeled_data[labeled_data["Label"] != labeled_data["Binary Label [Derived]"]]
k5.to_csv("k6.csv")

# %%
#don't use this cell
#k7 = labeled_data[labeled_data["Label"] == labeled_data["Binary Label [Derived]"]]
#k7.to_csv('first_test.csv')

# %%
# Testing
ob = labeled_data.iloc[1030]["Path Report"]

classify_breast_ob(ob)
if re.search(" carcinoma| cancer| malign| adenocarcinoma| Adenocarcinoma", ob):
    print('hi')
# Out:
# Left chest near scar, fine needle aspirate: Adenocarcinoma, consistent with breast primary. See comment.
# ['breast cancer', 'na', 'na']
# hi

# %%
#exporting
labeled_split_reps.to_csv("Labeled Path Reports (Specimen).csv")
labeled_data.to_csv("Labeled Path Reports (Entire Report).csv")

# %% [markdown]
# Analysis of Processed Data Charts

# %%
# Testing
labeled_data[labeled_data["Label"] != labeled_data["Binary Label [Derived]"]]
# Out:
#                                             Path Report               Label  \
# 28    A. Breast, needle-localization excision biopsy...      Right Positive
# 344   Right Breast, 10:00 o'clock, Fine Needle Aspir...            Negative
# 348   A. Left nipple, re-excision: Benign breast tis...       Left Positive
# 669   CONSULT SLIDE FROM WESTERN PATHOLOGY CONSULTAN...            Negative
# 863   1. Breast, left, excisional biopsy: Highly aty...       Left Positive
# 965   A. Right axillary lymph nodes, excision: Metas...      Right Positive
# 984   A. Node, site not further specified, sentinel ...            Negative
# 1030  Left chest near scar, fine needle aspirate: Ad...       Left Positive
# 1057  A. Right Chest Wall, Soft Tissue, Fine Needle ...      Right Positive
# 1207  A. BREAST, LEFT, FINE NEEDLE ASPIRATION: B cel...  Bilateral Positive
# 1427  Right Breast, Fine Needle Aspiration: Atypical...            Negative
# 1691  A. Uterus, hysterectomy: - Cervix: No signific...      Right Positive
# 2023  Right breast, "12 o'clock, 1 cm from nipple," ...            Negative
# 2030  A. Breast, Right, US-guided Fine Needle Aspira...      Right Positive
# 2032  A. Right axillary lymph node, fine-needle aspi...      Right Positive
# 2401  Site, procedure: Well-differentiated infiltrat...        Positive NOS
# 2744  A. Right breast, 2 cm from nipple 12 o'clock, ...       Left Positive
# 2966  A. Lymph node, left internal mammary, biopsy: ...       Left Positive
# 3145  A. Right Breast, "Intramammary Lymph Node" - 1...      Right Positive
# 3160  A. Left Breast,Upper Outer Quadrant, Fine Need...      Right Positive
# 3163  A. Left breast, posterior inferior capsule, bi...       Left Positive
# 3192  A. Left axillary lymph node, ultrasound-guided...  Bilateral Positive
# 3203  Right breast, slightly outer central, needle c...            Negative
# 3212  A: Right breast at 1:00 o'clock, 3 cm from the...            Negative
# 3252  Left Breast, Fine Needle Aspiration: Mammary c...            Negative
# 3286  A. Right axillary sentinel lymph node #1, diss...  Bilateral Positive
# 3299  A. Lymph nodes, right axilla, dissection: Meta...      Right Positive
# 3301  Right breast, posterior, biopsy: 1. Severely a...      Right Positive
# 3311  A. Left breast, upper inner, core needle biops...       Left Positive
# 3324  A. Left breast, excision: 1. Invasive ductal c...  Bilateral Positive
# 3393  A. Sentinel lymph node #1, left axilla, biopsy...       Left Positive
# 3420  to be reviewed by Dr. Miller A. Right Breast, ...      Right Positive
# 3677  A. Lymph node, "sentinel", biopsy: Metastatic ...        Positive NOS
#
#                                       Single Label Binary Label [Derived]
# 28                     (breast cancer, ductal, na)           Positive NOS
# 344                        (breast cancer, na, na)         Right Positive
# 348                               (benign, na, na)               Negative
# 669                  (breast cancer, na, invasive)          Left Positive
# 863                                   (na, na, na)               Negative
# 965                               (benign, na, na)               Negative
# 984                        (breast cancer, na, na)          Left Positive
# 1030                                  (na, na, na)               Negative
# 1057                                  (na, na, na)               Negative
# 1207                            (lymphoma, na, na)          Left Positive
# 1427                 (breast cancer, neoplasm, na)         Right Positive
# 1691                                  (na, na, na)               Negative
# 2023                       (breast cancer, na, na)         Right Positive
# 2030                              (benign, na, na)               Negative
# 2032                            (atypical, na, na)               Negative
# 2401                                  (na, na, na)               Negative
# 2744             (breast cancer, ductal, invasive)         Right Positive
# 2966                                  (na, na, na)               Negative
# 3145                                  (na, na, na)               Negative
# 3160                                  (na, na, na)               Negative
# 3163                                  (na, na, na)               Negative
# 3192                       (breast cancer, na, na)         Right Positive
# 3203              (breast cancer, ductal, in situ)         Right Positive
# 3212                   (breast cancer, ductal, na)         Right Positive
# 3252                       (breast cancer, na, na)          Left Positive
# 3286             (breast cancer, ductal, invasive)         Right Positive
# 3299  (atypical, atypical lobular hyperplasia, na)               Negative
# 3301                              (benign, na, na)               Negative
# 3311             (breast cancer, ductal, invasive)     Bilateral Positive
# 3324             (breast cancer, ductal, invasive)          Left Positive
# 3393             (benign, apocrine metaplasia, na)               Negative
# 3420                                  (na, na, na)               Negative
# 3677                                  (na, na, na)               Negative

# %%
split_reps.groupby("Single Label").agg(['count'])
# Out:
#                                                    Patient Biopsy Description  \
#                                                      count              count
# Single Label
# (atypical, atypical ductal hyperplasia, na)             73                 73
# (atypical, atypical lobular hyperplasia, na)            91                 91
# (atypical, fibroadenoma, na)                           316                316
# (atypical, flat epithelial atypia, na)                  35                 35
# (atypical, phyllodes, na)                               10                 10
# (benign, apocrine metaplasia, na)                      165                165
# (benign, cyst, na)                                     208                208
# (benign, mastitis, na)                                   4                  4
# (benign, na, na)                                      1144               1144
# (benign, papilloma, na)                                 50                 50
# (benign, pseudoangiomatous stromal hyperplasia,...      35                 35
# (benign, radial scar, na)                               17                 17
# (benign, sclerosing adenosis, na)                       62                 62
# (benign, usual ductal hyperplasia, na)                 203                203
# (breast cancer, ductal, in situ)                       472                472
# (breast cancer, ductal, invasive)                      573                573
# (breast cancer, ductal, na)                             87                 87
# (breast cancer, lobular, in situ)                       79                 79
# (breast cancer, lobular, invasive)                       1                  1
# (breast cancer, lobular, na)                            16                 16
# (breast cancer, na, in situ)                             2                  2
# (breast cancer, na, invasive)                           36                 36
# (breast cancer, na, na)                                297                297
# (breast cancer, neoplasm, na)                           10                 10
# (lymphoma, na, na)                                       5                  5
# (na, na, metastasis)                                     4                  4
# (na, na, na)                                          1709               1709
#
#                                                    Path Report Rad Label  \
#                                                          count     count
# Single Label
# (atypical, atypical ductal hyperplasia, na)                 73        73
# (atypical, atypical lobular hyperplasia, na)                91        91
# (atypical, fibroadenoma, na)                               316       316
# (atypical, flat epithelial atypia, na)                      35        35
# (atypical, phyllodes, na)                                   10        10
# (benign, apocrine metaplasia, na)                          165       165
# (benign, cyst, na)                                         208       208
# (benign, mastitis, na)                                       4         4
# (benign, na, na)                                          1144      1144
# (benign, papilloma, na)                                     50        50
# (benign, pseudoangiomatous stromal hyperplasia,...          35        35
# (benign, radial scar, na)                                   17        17
# (benign, sclerosing adenosis, na)                           62        62
# (benign, usual ductal hyperplasia, na)                     203       203
# (breast cancer, ductal, in situ)                           472       472
# (breast cancer, ductal, invasive)                          573       573
# (breast cancer, ductal, na)                                 87        87
# (breast cancer, lobular, in situ)                           79        79
# (breast cancer, lobular, invasive)                           1         1
# (breast cancer, lobular, na)                                16        16
# (breast cancer, na, in situ)                                 2         2
# (breast cancer, na, invasive)                               36        36
# (breast cancer, na, na)                                    297       297
# (breast cancer, neoplasm, na)                               10        10
# (lymphoma, na, na)                                           5         5
# (na, na, metastasis)                                         4         4
# (na, na, na)                                              1709      1709
#
#                                                    Laterality Biopsy Source  \
#                                                         count         count
# Single Label
# (atypical, atypical ductal hyperplasia, na)                73            73
# (atypical, atypical lobular hyperplasia, na)               91            91
# (atypical, fibroadenoma, na)                              316           316
# (atypical, flat epithelial atypia, na)                     35            35
# (atypical, phyllodes, na)                                  10            10
# (benign, apocrine metaplasia, na)                         165           165
# (benign, cyst, na)                                        208           208
# (benign, mastitis, na)                                      4             4
# (benign, na, na)                                         1144          1144
# (benign, papilloma, na)                                    50            50
# (benign, pseudoangiomatous stromal hyperplasia,...         35            35
# (benign, radial scar, na)                                  17            17
# (benign, sclerosing adenosis, na)                          62            62
# (benign, usual ductal hyperplasia, na)                    203           203
# (breast cancer, ductal, in situ)                          472           472
# (breast cancer, ductal, invasive)                         573           573
# (breast cancer, ductal, na)                                87            87
# (breast cancer, lobular, in situ)                          79            79
# (breast cancer, lobular, invasive)                          1             1
# (breast cancer, lobular, na)                               16            16
# (breast cancer, na, in situ)                                2             2
# (breast cancer, na, invasive)                              36            36
# (breast cancer, na, na)                                   297           297
# (breast cancer, neoplasm, na)                              10            10
# (lymphoma, na, na)                                          5             5
# (na, na, metastasis)                                        4             4
# (na, na, na)                                             1709          1709
#
#                                                    All Labels
#                                                         count
# Single Label
# (atypical, atypical ductal hyperplasia, na)                73
# (atypical, atypical lobular hyperplasia, na)               91
# (atypical, fibroadenoma, na)                              316
# (atypical, flat epithelial atypia, na)                     35
# (atypical, phyllodes, na)                                  10
# (benign, apocrine metaplasia, na)                         165
# (benign, cyst, na)                                        208
# (benign, mastitis, na)                                      4
# (benign, na, na)                                         1144
# (benign, papilloma, na)                                    50
# (benign, pseudoangiomatous stromal hyperplasia,...         35
# (benign, radial scar, na)                                  17
# (benign, sclerosing adenosis, na)                          62
# (benign, usual ductal hyperplasia, na)                    203
# (breast cancer, ductal, in situ)                          472
# (breast cancer, ductal, invasive)                         573
# (breast cancer, ductal, na)                                87
# (breast cancer, lobular, in situ)                          79
# (breast cancer, lobular, invasive)                          1
# (breast cancer, lobular, na)                               16
# (breast cancer, na, in situ)                                2
# (breast cancer, na, invasive)                              36
# (breast cancer, na, na)                                   297
# (breast cancer, neoplasm, na)                              10
# (lymphoma, na, na)                                          5
# (na, na, metastasis)                                        4
# (na, na, na)                                             1709

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    display(x)
    pd.reset_option('display.max_rows')
split_reps[split_reps["Single Label"] == ("benign", "cyst", "na")]#["Path Report"][4023]
# Out:
#       Patient                                 Biopsy Description  \
# 109        70         Skin, right breast, 1st incision, excision
# 141        96                                     Left Breast, 6
# 165       113             Left breast #1, fine needle aspiration
# 166       113             Left breast #2, fine needle aspiration
# 167       113             Left breast #3, fine needle aspiration
# 168       113             Left breast #4, fine needle aspiration
# 232       161               Right Breast, Fine Needle Aspiration
# 246       172            Right Breast #2, Fine Needle Aspiration
# 274       193                Left breast, fine needle aspiration
# 320       222                                   BREAST, RIGHT 10
# 321       222                                     BREAST, LEFT 2
# 339       235                Left breast, fine needle aspiration
# 350       242                               Breast, left, biopsy
# 371       261                Left Breast, Fine Needle Aspiration
# 401       284                     BREAST, FINE NEEDLE ASPIRATION
# 409       292            Left breast, needle localization biopsy
# 410       293                   Right breast, needle core biopsy
# 435       308                Left Breast, Fine Needle Aspiration
# 461       330               Right Breast, Fine Needle Aspiration
# 568       393    Breast, Left, Fine Needle Aspiration, 3 o'clock
# 572       395  Breast, left inferior, stereotactic core needl...
# 604       428                  Left breast, fine needle aspirate
# 616       438                              Breast, right, biopsy
# 617       439                                     Left Breast, 4
# 633       454               Right Breast, Fine Needle Aspiration
# 682       496               RIGHT BREAST, FINE NEEDLE ASPIRATION
# 718       525               Right Breast, Fine Needle Aspiration
# 735       535  Right Breast, Ultrasound-Guided Fine Needle As...
# 739       538               Right Breast, Fine Needle Aspiration
# 763       560               Right Breast, Fine Needle Aspiration
# ...       ...                                                ...
# 4001     2769                                     Left breast, 3
# 4043     2797               Right Breast, Fine Needle Aspiration
# 4091     2828                                   Right Breast @ 1
# 4100     2834          Right Breast Cyst, Fine Needle Aspiration
# 4113     2844                                    Right Breast, 1
# 4152     2866                Left Breast, Fine Needle Aspiration
# 4177     2885               Right Breast, Fine Needle Aspiration
# 4181     2888               Right Breast, Fine Needle Aspiration
# 4207     2907                                 Left Breast, at 11
# 4208     2908              Right upper outer breast, core biopsy
# 4222     2918               Right Breast, Fine Needle Aspiration
# 4240     2932  Breast, right, upper-outer quadrant, needle bi...
# 4286     2960                Left Breast, Fine Needle Aspiration
# 4290     2964  Right breast, tip of nipple, fine-needle aspir...
# 4304     2975                                   Right Breast, 10
# 4394     3037                                     Left Breast, 3
# 4399     3042                Left Breast, Fine Needle Aspiration
# 4403     3045                Left Breast, Fine Needle Aspiration
# 4425     3062                     Left breast, 6 o'clock, biopsy
# 4471     3091                         Left breast, needle biopsy
# 4912     3269                 Fallopian tube, left salpingectomy
# 5060     3338  Left Breast, Medial to Nipple - Retroareolar, ...
# 5204     3417                                     Left breast, 4
# 5220     3423                                     Left breast, 3
# 5232     3433        Right breast, "anterior inferior," excision
# 5521     3558  Uterus and bilateral tubes and ovaries, hyster...
# 5568     3589                     Breast, Fine Needle Aspiration
# 5576     3592                                         Breast, 10
# 5581     3596  Uterus, ovaries and tubes, abdominal hysterect...
# 5584     3597  Uterus, ovaries and tubes, abdominal hysterect...
#
#                                             Path Report       Rad Label  \
# 109    Skin with scar and epidermal inclusion cyst. ...        Negative
# 141   00, 3 cm from nipple, Fine Needle Aspiration. ...        Negative
# 165                     Benign cyst fluid; see comment.        Negative
# 166                     Benign cyst fluid; see comment.        Negative
# 167                     Benign cyst fluid; see comment.        Negative
# 168                     Benign cyst fluid; see comment.        Negative
# 232    Simple cyst and fibrocystic change; see comment.        Negative
# 246                                 Benign simple cyst.        Negative
# 274                     Benign cyst fluid; see comment.        Negative
# 320   00, FINE NEEDLE ASPIRATION.  Benign cyst with ...        Negative
# 321   00, FINE NEEDLE ASPIRATION.  Fibrocystic chang...        Negative
# 339                                  Benign cyst fluid.        Negative
# 350    Benign breast tissue and skin with ruptured e...        Negative
# 371    Fibrocystic change, see note. The fist pass, ...        Negative
# 401                     Benign cyst content, see below.        Negative
# 409    1. Fibrocystic alterations with apocrine meta...        Negative
# 410    Benign breast tissue with focal cyst formatio...        Negative
# 435                                         Simple cyst        Negative
# 461                                         Simple cyst        Negative
# 568    Cyst fluid and benign ductal epithelium, cons...        Negative
# 572    Fibrocystic change with interstitial fibrosis...        Negative
# 604                     Benign cyst fluid. See comment.        Negative
# 616                           Benign cyst; see comment.        Negative
# 617   00 O'Clock, Fine Needle Aspiration.  Cyst flui...        Negative
# 633                           Simple cyst, see comment.        Negative
# 682        Benign- Fibrocystic change with benign cyst.        Negative
# 718                     Benign cyst fluid. See comment.        Negative
# 735              Proteinaceous cyst fluid; see comment.        Negative
# 739                                 Benign simple cyst.        Negative
# 763    Benign breast cyst contents. COMMENT.  The sa...        Negative
# ...                                                 ...             ...
# 4001  00 position, 14 cm from nipple, ultrasound-gui...        Negative
# 4043                                       Benign cyst.        Negative
# 4091  00, 3 cm from nipple, Fine Needle Aspiration. ...        Negative
# 4100                                       Benign cyst.        Negative
# 4113  00, Fine Needle Aspiration.  Benign cyst fluid...        Negative
# 4152                                Cyst ; see comment.        Negative
# 4177                 Benign cyst contents, see comment.        Negative
# 4181                 Benign cyst contents; see comment.        Negative
# 4207  30 o'clock, Fine Needle Aspiration.  Benign cy...        Negative
# 4208   1. Pseudoangiomatous hyperplasia. 2. Calcific...        Negative
# 4222                               Benign Cyst Contents        Negative
# 4240   Fibrocystic changes with stromal fibrosis, cy...        Negative
# 4286                          Benign cyst; see comment.        Negative
# 4290             Epidermal inclusion cyst, see comment.        Negative
# 4304  00 O'Clock, Fine Needle Aspiration.  Cyst flui...        Negative
# 4394  00, Fine Needle Aspiration.  Cyst contents; se...        Negative
# 4399                                        Simple cyst        Negative
# 4403                                       Benign cyst.        Negative
# 4425   Fragments of simple cyst wall with detached f...        Negative
# 4471   1. Proliferative fibrocystic changes includin...        Negative
# 4912                             Benign paratubal cyst.  Right Positive
# 5060                                 Benign cyst fluid.   Left Positive
# 5204  00 o'clock, US guided FNA biopsy.  Inspissated...   Left Positive
# 5220  00 o'clock, 6 cm from the nipple, US-guided FN...   Left Positive
# 5232   1. Biopsy site changes. 2. Microscopic benign...  Right Positive
# 5521   -Endometrium.  1. Mixed glandular pattern; se...        Negative
# 5568                                        Simple cyst        Negative
# 5576  30, Fine Needle Aspiration.  Cyst Content; see...        Negative
# 5581   -Cervix.  No significant pathologic abnormali...        Negative
# 5584   -Cervix.  No significant pathologic abnormali...        Negative
#
#      Laterality Biopsy Source  \
# 109       right        breast
# 141        left        breast
# 165        left        breast
# 166        left        breast
# 167        left        breast
# 168        left        breast
# 232       right        breast
# 246       right        breast
# 274        left        breast
# 320       right        breast
# 321        left        breast
# 339        left        breast
# 350        left        breast
# 371        left        breast
# 401          na        breast
# 409        left        breast
# 410       right        breast
# 435        left        breast
# 461       right        breast
# 568        left        breast
# 572        left        breast
# 604        left        breast
# 616       right        breast
# 617        left        breast
# 633       right        breast
# 682       right        breast
# 718       right        breast
# 735       right        breast
# 739       right        breast
# 763       right        breast
# ...         ...           ...
# 4001       left        breast
# 4043      right        breast
# 4091      right        breast
# 4100      right        breast
# 4113      right        breast
# 4152       left        breast
# 4177      right        breast
# 4181      right        breast
# 4207       left        breast
# 4208      right        breast
# 4222      right        breast
# 4240      right        breast
# 4286       left        breast
# 4290      right        breast
# 4304      right        breast
# 4394       left        breast
# 4399       left        breast
# 4403       left        breast
# 4425       left        breast
# 4471       left        breast
# 4912       left        breast
# 5060       left        breast
# 5204       left        breast
# 5220       left        breast
# 5232      right        breast
# 5521         na        breast
# 5568         na        breast
# 5576         na        breast
# 5581         na        breast
# 5584         na        breast
#
#                                              All Labels        Single Label
# 109                                [[benign, cyst, na]]  (benign, cyst, na)
# 141                                [[benign, cyst, na]]  (benign, cyst, na)
# 165                                [[benign, cyst, na]]  (benign, cyst, na)
# 166                                [[benign, cyst, na]]  (benign, cyst, na)
# 167                                [[benign, cyst, na]]  (benign, cyst, na)
# 168                                [[benign, cyst, na]]  (benign, cyst, na)
# 232                                [[benign, cyst, na]]  (benign, cyst, na)
# 246                                [[benign, cyst, na]]  (benign, cyst, na)
# 274                                [[benign, cyst, na]]  (benign, cyst, na)
# 320                                [[benign, cyst, na]]  (benign, cyst, na)
# 321                                [[benign, cyst, na]]  (benign, cyst, na)
# 339                                [[benign, cyst, na]]  (benign, cyst, na)
# 350                                [[benign, cyst, na]]  (benign, cyst, na)
# 371                                [[benign, cyst, na]]  (benign, cyst, na)
# 401                                [[benign, cyst, na]]  (benign, cyst, na)
# 409   [[na, na, na], [benign, apocrine metaplasia, n...  (benign, cyst, na)
# 410                                [[benign, cyst, na]]  (benign, cyst, na)
# 435                                [[benign, cyst, na]]  (benign, cyst, na)
# 461                                [[benign, cyst, na]]  (benign, cyst, na)
# 568                                [[benign, cyst, na]]  (benign, cyst, na)
# 572                                [[benign, cyst, na]]  (benign, cyst, na)
# 604                                [[benign, cyst, na]]  (benign, cyst, na)
# 616                                [[benign, cyst, na]]  (benign, cyst, na)
# 617                                [[benign, cyst, na]]  (benign, cyst, na)
# 633                                [[benign, cyst, na]]  (benign, cyst, na)
# 682                                [[benign, cyst, na]]  (benign, cyst, na)
# 718                                [[benign, cyst, na]]  (benign, cyst, na)
# 735                                [[benign, cyst, na]]  (benign, cyst, na)
# 739                                [[benign, cyst, na]]  (benign, cyst, na)
# 763                                [[benign, cyst, na]]  (benign, cyst, na)
# ...                                                 ...                 ...
# 4001                               [[benign, cyst, na]]  (benign, cyst, na)
# 4043                               [[benign, cyst, na]]  (benign, cyst, na)
# 4091                               [[benign, cyst, na]]  (benign, cyst, na)
# 4100                               [[benign, cyst, na]]  (benign, cyst, na)
# 4113                               [[benign, cyst, na]]  (benign, cyst, na)
# 4152                               [[benign, cyst, na]]  (benign, cyst, na)
# 4177                               [[benign, cyst, na]]  (benign, cyst, na)
# 4181                               [[benign, cyst, na]]  (benign, cyst, na)
# 4207                               [[benign, cyst, na]]  (benign, cyst, na)
# 4208  [[na, na, na], [na, na, na], [na, na, na], [be...  (benign, cyst, na)
# 4222                               [[benign, cyst, na]]  (benign, cyst, na)
# 4240                               [[benign, cyst, na]]  (benign, cyst, na)
# 4286                               [[benign, cyst, na]]  (benign, cyst, na)
# 4290                               [[benign, cyst, na]]  (benign, cyst, na)
# 4304                               [[benign, cyst, na]]  (benign, cyst, na)
# 4394                               [[benign, cyst, na]]  (benign, cyst, na)
# 4399                               [[benign, cyst, na]]  (benign, cyst, na)
# 4403                               [[benign, cyst, na]]  (benign, cyst, na)
# 4425                               [[benign, cyst, na]]  (benign, cyst, na)
# 4471  [[na, na, na], [benign, usual ductal hyperplas...  (benign, cyst, na)
# 4912                               [[benign, cyst, na]]  (benign, cyst, na)
# 5060                               [[benign, cyst, na]]  (benign, cyst, na)
# 5204                               [[benign, cyst, na]]  (benign, cyst, na)
# 5220                               [[benign, cyst, na]]  (benign, cyst, na)
# 5232  [[na, na, na], [na, na, na], [benign, cyst, na...  (benign, cyst, na)
# 5521  [[na, na, na], [na, na, na], [na, na, na], [na...  (benign, cyst, na)
# 5568                               [[benign, cyst, na]]  (benign, cyst, na)
# 5576                               [[benign, cyst, na]]  (benign, cyst, na)
# 5581                               [[benign, cyst, na]]  (benign, cyst, na)
# 5584                               [[benign, cyst, na]]  (benign, cyst, na)
#
# [208 rows x 8 columns]
